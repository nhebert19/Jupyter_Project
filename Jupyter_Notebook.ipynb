# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, data science tools and ecosystems are summarized.

# %% [markdown]
# __Objective__:
# - List popular languages for data science
# - List popular libraries for data science
# - Convert 200 minutes to hours

# %% [markdown]
# The most common languages used for data science are :
# 1. Python
# 2. R
# 3. SQL
#
# However, other languages such as Julia, Visual Basic, JavaScript, Java, Scala, SAS, MATLAB, C, C++ and Swift can be used for data science.

# %% [markdown]
# Some of the most common data science libraries are :
# 1. Pandas
# 2. NumPy
# 3. Seaborn
# 4. Matplotlib
# 5. TensorFlow
# 6. Scikit-Learn
# 7. SciPy
# 8. PyTorch

# %% [markdown]
# |Data Science Tools|
# |:----------------:|
# |Apache Spark      |
# |Apache Hadoop     |
# |KNIME             |

# %% [markdown]
# Below are a few examples of evaluationg arithmetic expressions in python.

# %%
# This is a simple arithmetic expression to multiply and then add integers. 
(3*4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours. 
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Nicholas Hebert
